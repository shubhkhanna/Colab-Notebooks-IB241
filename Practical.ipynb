# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhkhanna/Colab-Notebooks-IB241/blob/master/Practical" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical 1

# %% [markdown]
# #### Import Car_Sales Data and remove Unnamed 0 and XX columns.

# %%
import pandas as pd
import numpy as np

# %%
carData = pd.read_csv('https://raw.githubusercontent.com/shubhkhanna/Colab-Notebooks-IB241/master/DataSet/Car_sales.csv')
carData
# Out:
#       Manufacturer              Model  ...  Unnamed: 15      XX
# 0    Acura          Integra            ...          NaN  16.360
# 1    Acura          TL                 ...          NaN  19.875
# 2    Acura          CL                 ...          NaN  18.225
# 3    Acura          RL                 ...          NaN  29.725
# 4    Audi           A4                 ...          NaN  22.255
# ..             ...                ...  ...          ...     ...
# 152  Volvo          V40                ...          NaN     NaN
# 153  Volvo          S70                ...          NaN     NaN
# 154  Volvo          V70                ...          NaN     NaN
# 155  Volvo          C70                ...          NaN     NaN
# 156  Volvo          S80                ...          NaN     NaN
#
# [157 rows x 17 columns]

# %%
# Removing Unamed and XX column 
newCarData = carData.drop(['Unnamed: 15','XX'],axis=1)
newCarData
# Out:
#       Manufacturer              Model  ...  Fuel efficiency  Latest Launch
# 0    Acura          Integra            ...             28.0       2-Feb-14
# 1    Acura          TL                 ...             25.0       6-Mar-15
# 2    Acura          CL                 ...             26.0       1-Apr-14
# 3    Acura          RL                 ...             22.0       3-Oct-15
# 4    Audi           A4                 ...             27.0      10-Aug-15
# ..             ...                ...  ...              ...            ...
# 152  Volvo          V40                ...             25.0      21-Sep-15
# 153  Volvo          S70                ...             25.0      24-Nov-14
# 154  Volvo          V70                ...             25.0      25-Jun-15
# 155  Volvo          C70                ...             23.0      26-Apr-15
# 156  Volvo          S80                ...             24.0      14-Nov-15
#
# [157 rows x 15 columns]

# %% [markdown]
# # Practical 2

# %% [markdown]
# ## Mean Imputation of all the columns and Export the file

# %%
# Mean Imputation
newCarData.mean()
# Out:
# Sales in thousands     52.998076
# x_4_year               18.072975
# Price in thousands     27.390755
# Engine size             3.060897
# Horsepower            185.948718
# Wheelbase             107.487179
# Width                  71.150000
# Length                187.343590
# Curb weight             3.378026
# Fuel capacity          17.951923
# Fuel efficiency        23.844156
# dtype: float64

# %%
# Exporting File
newCarData.to_csv("New_Car_Data.csv")

# %% [markdown]
# # Practical 3

# %% [markdown]
# ## Grouping the Manufacturers data with the mean and sum of the Sales in thousands column.

# %%
df1 = newCarData.iloc[:,[0,2]]
df1
# Out:
#       Manufacturer  Sales in thousands
# 0    Acura                      16.919
# 1    Acura                      39.384
# 2    Acura                      14.114
# 3    Acura                       8.588
# 4    Audi                       20.397
# ..             ...                 ...
# 152  Volvo                       3.545
# 153  Volvo                      15.245
# 154  Volvo                      17.531
# 155  Volvo                       3.493
# 156  Volvo                      18.969
#
# [157 rows x 2 columns]

# %%
df1.groupby('Manufacturer').mean()
# Out:
#                Sales in thousands
# Manufacturer
# Acura                   19.751250
# Audi                    13.519000
# BMW                     15.501667
# Buick                   60.504750
# Cadillac                22.435600
# Chevrolet               61.596111
# Chrysler                28.817286
# Dodge                   82.740818
# Ford                   183.875909
# Honda                  118.534800
# Hyundai                 45.775333
# Infiniti                23.713000
# Jaguar                  15.467000
# Jeep                    97.717667
# Lexus                   17.807167
# Lincoln                 28.544667
# Mercedes-Benz           13.013889
# Mercury                 39.666500
# Mitsubishi              25.842143
# Nissan                  57.090714
# Oldsmobile              29.831500
# Plymouth                16.000250
# Pontiac                 61.755667
# Porsche                  4.042667
# Saab                    10.653000
# Saturn                  33.770000
# ...

# %%
df1.groupby('Manufacturer').sum()
# Out:
#                Sales in thousands
# Manufacturer
# Acura                      79.005
# Audi                       40.557
# BMW                        46.505
# Buick                     242.019
# Cadillac                  112.178
# Chevrolet                 554.365
# Chrysler                  201.721
# Dodge                     910.149
# Ford                     2022.635
# Honda                     592.674
# Hyundai                   137.326
# Infiniti                   23.713
# Jaguar                     15.467
# Jeep                      293.153
# Lexus                     106.843
# Lincoln                    85.634
# Mercedes-Benz             117.125
# Mercury                   237.999
# Mitsubishi                180.895
# Nissan                    399.635
# Oldsmobile                178.989
# Plymouth                   64.001
# Pontiac                   370.534
# Porsche                    12.128
# Saab                       21.306
# Saturn                    168.850
# ...

# %% [markdown]
# # Practical 4

# %% [markdown]
# '''
# Condition based programming on Car_Sales data
# Fetch the company name who has got highest price with respect to minimum number of sales figures.
# Fetch the name of the model and company's name which have lowest sales with respect to Vehicle Type Passenger
# Fetch the model and company name whose Sales and Fuel_Efficiency is Highest but Price is lowest.
# '''

# %%
df1 = newCarData.iloc[:,[0,2,5]]
df1
# Out:
#       Manufacturer  Sales in thousands  Price in thousands
# 0    Acura                      16.919               21.50
# 1    Acura                      39.384               28.40
# 2    Acura                      14.114                 NaN
# 3    Acura                       8.588               42.00
# 4    Audi                       20.397               23.99
# ..             ...                 ...                 ...
# 152  Volvo                       3.545               24.40
# 153  Volvo                      15.245               27.50
# 154  Volvo                      17.531               28.80
# 155  Volvo                       3.493               45.50
# 156  Volvo                      18.969               36.00
#
# [157 rows x 3 columns]

# %%
df = df1.groupby('Sales in thousands').min()
df
# Out:
#                      Manufacturer  Price in thousands
# Sales in thousands
# 0.110               Mitsubishi                 25.450
# 0.916               Dodge                      69.725
# 0.954               Mercedes-Benz              85.500
# 1.112               Oldsmobile                 18.145
# 1.280               Porsche                    71.020
# ...                           ...                 ...
# 230.902             Honda                      15.350
# 245.815             Ford                       17.885
# 247.994             Toyota                     17.518
# 276.747             Ford                       31.930
# 540.561             Ford                       26.935
#
# [157 rows x 2 columns]

# %%
df.max()
# Out:
# Manufacturer          Volvo
# Price in thousands             85.5
# dtype: object

# %%
df1 = newCarData.iloc[:,[0,1,2,4]]
df1 = df1[df1["Vehicle type"] == "Passenger"]
df1
# Out:
#       Manufacturer              Model  Sales in thousands Vehicle type
# 0    Acura          Integra                        16.919    Passenger
# 1    Acura          TL                             39.384    Passenger
# 2    Acura          CL                             14.114    Passenger
# 3    Acura          RL                              8.588    Passenger
# 4    Audi           A4                             20.397    Passenger
# ..             ...                ...                 ...          ...
# 152  Volvo          V40                             3.545    Passenger
# 153  Volvo          S70                            15.245    Passenger
# 154  Volvo          V70                            17.531    Passenger
# 155  Volvo          C70                             3.493    Passenger
# 156  Volvo          S80                            18.969    Passenger
#
# [116 rows x 4 columns]

# %%
new = df1.groupby('Sales in thousands').min()
new
# Out:
#                      Manufacturer              Model Vehicle type
# Sales in thousands
# 0.110               Mitsubishi     3000GT               Passenger
# 0.916               Dodge          Viper                Passenger
# 0.954               Mercedes-Benz  CL500                Passenger
# 1.112               Oldsmobile     Cutlass              Passenger
# 1.280               Porsche        Carrera Coupe        Passenger
# ...                           ...                ...          ...
# 175.670             Ford           Focus                Passenger
# 199.685             Honda          Civic                Passenger
# 230.902             Honda          Accord               Passenger
# 245.815             Ford           Taurus               Passenger
# 247.994             Toyota         Camry                Passenger
#
# [116 rows x 3 columns]

# %% [markdown]
# #### Lowest Sales is of Company = Mitsubishi, Model = 3000GT

# %%
df1 = newCarData.iloc[:,[0,1,2,5,13]]
df1
# Out:
#       Manufacturer              Model  ...  Price in thousands  Fuel efficiency
# 0    Acura          Integra            ...               21.50             28.0
# 1    Acura          TL                 ...               28.40             25.0
# 2    Acura          CL                 ...                 NaN             26.0
# 3    Acura          RL                 ...               42.00             22.0
# 4    Audi           A4                 ...               23.99             27.0
# ..             ...                ...  ...                 ...              ...
# 152  Volvo          V40                ...               24.40             25.0
# 153  Volvo          S70                ...               27.50             25.0
# 154  Volvo          V70                ...               28.80             25.0
# 155  Volvo          C70                ...               45.50             23.0
# 156  Volvo          S80                ...               36.00             24.0
#
# ...

# %%
df1 = df1.groupby('Sales in thousands').max()
df2 = df1.groupby('Fuel efficiency').max()
df2.groupby('Price in thousands').min()
# Out:
#                      Manufacturer              Model
# Price in thousands
# 9.235               Chevrolet      Metro
# 12.640              Plymouth       Neon
# 12.885              Honda          Civic
# 13.960              Toyota         SL
# 16.540              Nissan         Sentra
# 16.875              Toyota         SW
# 21.500              Saturn         Mystique
# 26.310              Jeep           Wrangler
# 31.807              Nissan         Xterra
# 31.930              Oldsmobile     Pathfinder
# 36.000              Volvo          Voyager
# 41.000              Volkswagen     Sunfire
# 41.600              Volkswagen     SLK
# 49.900              Volvo          V70
# 54.005              Toyota         Silhouette
# 60.105              Toyota         Ram Wagon
# 69.725              Ford           Viper
# 71.020              Porsche        Windstar
# 74.970              Volvo          Tacoma
# 85.500              Mitsubishi     SL-Class

# %% [markdown]
# # Practical 5

# %%
plaData = pd.read_csv('https://raw.githubusercontent.com/shubhkhanna/Colab-Notebooks-IB241/master/DataSet/Placement_Data.csv')
plaData
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0        1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1        2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2        3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3        4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       NaN
# 4        5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
# ..     ...    ...    ...      ...  ...             ...    ...         ...       ...
# 210    211      M  80.60   Others  ...         Mkt&Fin  74.49      Placed  400000.0
# 211    212      M  58.00   Others  ...         Mkt&Fin  53.62      Placed  275000.0
# 212    213      M  67.00   Others  ...         Mkt&Fin  69.72      Placed  295000.0
# 213    214      F  74.00   Others  ...          Mkt&HR  60.23      Placed  204000.0
# ...

# %%
male = plaData[plaData["gender"] == 'M']
male
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0        1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1        2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2        3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3        4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       NaN
# 4        5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
# ..     ...    ...    ...      ...  ...             ...    ...         ...       ...
# 209    210      M  62.00  Central  ...         Mkt&Fin  56.49      Placed  216000.0
# 210    211      M  80.60   Others  ...         Mkt&Fin  74.49      Placed  400000.0
# 211    212      M  58.00   Others  ...         Mkt&Fin  53.62      Placed  275000.0
# 212    213      M  67.00   Others  ...         Mkt&Fin  69.72      Placed  295000.0
# ...

# %%
comm = male[male['hsc_s'] == 'Commerce']
comm
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0        1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 4        5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
# 8        9      M  73.00  Central  ...         Mkt&Fin  61.29      Placed  231000.0
# 9       10      M  58.00  Central  ...         Mkt&Fin  52.21  Not Placed       NaN
# 10      11      M  58.00  Central  ...          Mkt&HR  60.85      Placed  260000.0
# ..     ...    ...    ...      ...  ...             ...    ...         ...       ...
# 205    206      M  61.00   Others  ...         Mkt&Fin  56.81      Placed  250000.0
# 207    208      M  83.33  Central  ...         Mkt&Fin  71.55      Placed  300000.0
# 209    210      M  62.00  Central  ...         Mkt&Fin  56.49      Placed  216000.0
# 210    211      M  80.60   Others  ...         Mkt&Fin  74.49      Placed  400000.0
# ...

# %%
lowest = comm.groupby('salary').min()
lowest
# Out:
#           sl_no gender  ssc_p    ssc_b  ...  etest_p specialisation  mba_p  status
# salary                                  ...
# 200000.0    108      M  82.00   Others  ...    80.00         Mkt&HR  73.52  Placed
# 204000.0     48      M  63.00  Central  ...    78.00        Mkt&Fin  54.55  Placed
# 216000.0    210      M  62.00  Central  ...    67.00        Mkt&Fin  56.49  Placed
# 218000.0     74      M  64.60  Central  ...    86.00        Mkt&Fin  59.75  Placed
# 220000.0     87      M  62.00  Central  ...    58.00        Mkt&Fin  54.43  Placed
# 225000.0    138      M  67.00   Others  ...    56.00         Mkt&HR  60.41  Placed
# 231000.0      9      M  73.00  Central  ...    91.34        Mkt&Fin  61.29  Placed
# 240000.0     27      M  62.00   Others  ...    60.00        Mkt&Fin  52.38  Placed
# 250000.0     12      M  58.00  Central  ...    58.00        Mkt&Fin  53.94  Placed
# 260000.0     11      M  55.68  Central  ...    53.88        Mkt&Fin  54.97  Placed
# ...

# %%
sci = plaData[plaData['degree_t'] == 'Sci&Tech']
coms = sci[sci['hsc_s'] == 'Commerce']
ls = coms.groupby('salary').min()
ls
# Out:
#           sl_no gender  ssc_p   ssc_b  ...  etest_p specialisation mba_p  status
# salary                                 ...
# 270000.0      1      M   67.0  Others  ...     55.0         Mkt&HR  58.8  Placed
#
# [1 rows x 14 columns]

# %%
new = plaData[plaData['workex'] == 'No']
ls = new.groupby('salary').max()
ls
# Out:
#           sl_no gender  ssc_p    ssc_b  ...  etest_p specialisation  mba_p  status
# salary                                  ...
# 200000.0    136      M  82.00   Others  ...    80.00         Mkt&HR  73.52  Placed
# 204000.0    214      F  74.00   Others  ...    70.00         Mkt&HR  60.23  Placed
# 210000.0     89      F  66.00  Central  ...    58.00         Mkt&HR  64.36  Placed
# 216000.0    210      M  74.00   Others  ...    89.00         Mkt&HR  65.56  Placed
# 218000.0     74      M  77.00  Central  ...    86.00        Mkt&Fin  68.63  Placed
# 220000.0    177      M  69.00   Others  ...    71.00         Mkt&HR  57.90  Placed
# 225000.0    138      M  67.00   Others  ...    56.00         Mkt&HR  60.41  Placed
# 230000.0     93      F  66.50   Others  ...    72.00        Mkt&Fin  64.27  Placed
# 231000.0      9      M  73.00  Central  ...    91.34        Mkt&Fin  61.29  Placed
# 233000.0    147      M  62.00  Central  ...    85.00         Mkt&HR  55.14  Placed
# ...
