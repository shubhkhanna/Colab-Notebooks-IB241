# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhkhanna/Colab-Notebooks-IB241/blob/master/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/shubhkhanna/Colab-Notebooks-IB241/master/DataSet/Ufo.csv")
df
# Out:
#        Unnamed: 0                  City  ... State              Time
# 0               0                Ithaca  ...    NY    6/1/1930 22:00
# 1               1           Willingboro  ...    NJ   6/30/1930 20:00
# 2               2               Holyoke  ...    CO   2/15/1931 14:00
# 3               3               Abilene  ...    KS    6/1/1931 13:00
# 4               4  New York Worlds Fair  ...    NY   4/18/1933 19:00
# ...           ...                   ...  ...   ...               ...
# 18236       18236            Grant Park  ...    IL  12/31/2000 23:00
# 18237       18237           Spirit Lake  ...    IA  12/31/2000 23:00
# 18238       18238           Eagle River  ...    WI  12/31/2000 23:45
# 18239       18239           Eagle River  ...    WI  12/31/2000 23:45
# 18240       18240                  Ybor  ...    FL  12/31/2000 23:59
#
# [18241 rows x 6 columns]

# %%
df.loc[0:5,"City"]
# Out:
# 0                  Ithaca
# 1             Willingboro
# 2                 Holyoke
# 3                 Abilene
# 4    New York Worlds Fair
# 5             Valley City
# Name: City, dtype: object

# %%
df.iloc[[0,1,2,3],[2,4]]
# Out:
#   Colors Reported State
# 0             Red    NY
# 1             Red    NJ
# 2             Red    CO
# 3             Red    KS

# %%
df.iloc[[1,3,5,7,9],:]
# Out:
#    Unnamed: 0         City  ... State             Time
# 1           1  Willingboro  ...    NJ  6/30/1930 20:00
# 3           3      Abilene  ...    KS   6/1/1931 13:00
# 5           5  Valley City  ...    ND  9/15/1934 15:30
# 7           7         Alma  ...    MI   7/15/1936 0:00
# 9           9      Hubbard  ...    OR   6/15/1937 0:00
#
# [5 rows x 6 columns]

# %%
df.loc[[0,1,2],["State","Time"]]
# Out:
#   State             Time
# 0    NY   6/1/1930 22:00
# 1    NJ  6/30/1930 20:00
# 2    CO  2/15/1931 14:00

# %%
df=df.iloc[:,1:]
df
# Out:
#                        City Colors Reported  ... State              Time
# 0                    Ithaca             Red  ...    NY    6/1/1930 22:00
# 1               Willingboro             Red  ...    NJ   6/30/1930 20:00
# 2                   Holyoke             Red  ...    CO   2/15/1931 14:00
# 3                   Abilene             Red  ...    KS    6/1/1931 13:00
# 4      New York Worlds Fair             Red  ...    NY   4/18/1933 19:00
# ...                     ...             ...  ...   ...               ...
# 18236            Grant Park             Red  ...    IL  12/31/2000 23:00
# 18237           Spirit Lake             Red  ...    IA  12/31/2000 23:00
# 18238           Eagle River             Red  ...    WI  12/31/2000 23:45
# 18239           Eagle River             RED  ...    WI  12/31/2000 23:45
# 18240                  Ybor             Red  ...    FL  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
df.iloc[:,]
# Out:
#                        City Colors Reported  ... State              Time
# 0                    Ithaca             Red  ...    NY    6/1/1930 22:00
# 1               Willingboro             Red  ...    NJ   6/30/1930 20:00
# 2                   Holyoke             Red  ...    CO   2/15/1931 14:00
# 3                   Abilene             Red  ...    KS    6/1/1931 13:00
# 4      New York Worlds Fair             Red  ...    NY   4/18/1933 19:00
# ...                     ...             ...  ...   ...               ...
# 18236            Grant Park             Red  ...    IL  12/31/2000 23:00
# 18237           Spirit Lake             Red  ...    IA  12/31/2000 23:00
# 18238           Eagle River             Red  ...    WI  12/31/2000 23:45
# 18239           Eagle River             RED  ...    WI  12/31/2000 23:45
# 18240                  Ybor             Red  ...    FL  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# City               0
# Colors Reported    0
# Shape Reported     0
# State              0
# Time               0
# dtype: int64

# %%
df["City"].value_counts( ) #checking repeated city
# Out:
# Seattle           187
# New York City     161
# Phoenix           137
# Houston           108
# Las Vegas         105
#                  ...
# Plattsburgh         1
# North Lynnwood      1
# Bradley             1
# St. Maries          1
# Upper Freehold      1
# Name: City, Length: 6477, dtype: int64

# %%
print(df[df["City"] == "Seattle"])
print(df[df["City"] == "San Diego"])
print(df[df["City"] == "Miami"])
print(df[df["City"] == "Springfield"])
print(df[df["City"] == "Albuquerque"])
print(df[df["City"] == "Tucson"])
print(df[df["City"] == "Colorado Springs"])
print(df.loc[df["City"] == "Jacksonville"])
# Out:
#           City Colors Reported Shape Reported State              Time
# 68     Seattle             Red           OVAL    WA    7/4/1947 17:30
# 99     Seattle             Red           DISK    WA   4/10/1949 15:00
# 591    Seattle           GREEN           OVAL    WA     6/1/1960 0:00
# 640    Seattle             Red           DISK    WA   9/15/1960 20:30
# 732    Seattle             Red          OTHER    WA    7/1/1962 22:00
# ...        ...             ...            ...   ...               ...
# 17773  Seattle             Red       TRIANGLE    WA  10/25/2000 20:30
# 17788  Seattle             Red           OVAL    WA  10/27/2000 10:30
# 17865  Seattle             Red          LIGHT    WA    11/3/2000 0:45
# 18004  Seattle             Red          LIGHT    WA   11/23/2000 1:03
# 18176  Seattle             Red          LIGHT    WA  12/23/2000 20:00
#
# [187 rows x 5 columns]
#             City Colors Reported Shape Reported State              Time
# ...

# %%
df[(df["City"] == "Seattle") & (df["Shape Reported"] == "OTHER") ]
# Out:
#           City Colors Reported Shape Reported State             Time
# 732    Seattle             Red          OTHER    WA   7/1/1962 22:00
# 5464   Seattle             Red          OTHER    WA  6/30/1986 14:00
# 6714   Seattle             Red          OTHER    WA    1/1/1992 0:00
# 9353   Seattle             Red          OTHER    WA    6/1/1996 7:00
# 9385   Seattle             Red          OTHER    WA  6/11/1996 15:00
# 10121  Seattle             Red          OTHER    WA   4/3/1997 17:30
# 10419  Seattle             Red          OTHER    WA   6/20/1997 4:30
# 10788  Seattle             Red          OTHER    WA  9/19/1997 21:00
# 12121  Seattle          ORANGE          OTHER    WA  9/15/1998 18:00
# 15300  Seattle             Red          OTHER    WA  11/17/1999 0:00
# 15819  Seattle             Red          OTHER    WA   2/2/2000 19:49
# 15820  Seattle             Red          OTHER    WA   2/2/2000 19:49
# 16339  Seattle             Red          OTHER    WA  4/28/2000 22:10
# ...

# %%
df.loc[(df["City"] == "Los Angeles") & (df["Shape Reported"] == "LIGHT"), ["City", "Time", "Shape Reported"] ]
# Out:
#               City              Time Shape Reported
# 16     Los Angeles    2/25/1942 0:00          LIGHT
# 2236   Los Angeles   6/20/1972 20:00          LIGHT
# 3714   Los Angeles     4/4/1978 2:00          LIGHT
# 4088   Los Angeles    6/15/1979 4:30          LIGHT
# 4278   Los Angeles     5/5/1980 4:00          LIGHT
# 6336   Los Angeles   6/10/1990 20:00          LIGHT
# 7651   Los Angeles   12/30/1994 2:05          LIGHT
# 8602   Los Angeles    8/27/1995 4:00          LIGHT
# 9745   Los Angeles   11/20/1996 0:00          LIGHT
# 9768   Los Angeles  11/29/1996 19:05          LIGHT
# 10176  Los Angeles   4/21/1997 21:20          LIGHT
# 10917  Los Angeles   11/1/1997 22:00          LIGHT
# 11752  Los Angeles   6/30/1998 23:00          LIGHT
# 12928  Los Angeles   1/18/1999 18:20          LIGHT
# 13677  Los Angeles   6/12/1999 22:00          LIGHT
# 14792  Los Angeles   10/11/1999 4:30          LIGHT
# 15085  Los Angeles   11/13/1999 2:30          LIGHT
# ...

# %%
a = pd.DataFrame(df.head().values,columns=[1,2,3,4,5])
a
# Out:
#                       1    2         3   4                5
# 0                Ithaca  Red  TRIANGLE  NY   6/1/1930 22:00
# 1           Willingboro  Red     OTHER  NJ  6/30/1930 20:00
# 2               Holyoke  Red      OVAL  CO  2/15/1931 14:00
# 3               Abilene  Red      DISK  KS   6/1/1931 13:00
# 4  New York Worlds Fair  Red     LIGHT  NY  4/18/1933 19:00
